# %%
# importing Required libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sklearn as preprocessing 
from sklearn.impute import SimpleImputer

# %%
#read dataset
data= pd.read_csv (r"C:\Users\anish\Desktop\project_research\Projectdata .xlsx.csv")

# %%
data
# Out:
#       Typeofsales   Patient_ID    Specialisation         Dept  Dateofbill  \
# 0            Sale  12018098765   Specialisation6  Department1  06-01-2022
# 1            Sale  12018103897   Specialisation7  Department1   7/23/2022
# 2            Sale  12018101123   Specialisation2  Department3   6/23/2022
# 3            Sale  12018079281  Specialisation40  Department1   3/17/2022
# 4            Sale  12018117928   Specialisation5  Department1  12/21/2022
# ...           ...          ...               ...          ...         ...
# 14213        Sale  12018099994  Specialisation39  Department1   6/19/2022
# 14214        Sale  12018047025   Specialisation4  Department1   2/24/2022
# 14215        Sale  12018017139   Specialisation1  Department1   6/27/2022
# 14216        Sale  12018044140  Specialisation20  Department1   7/30/2022
# 14217        Sale  12018116820  Specialisation26  Department1  10/24/2022
#
#        Quantity  ReturnQuantity  Final_Cost  Final_Sales  RtnMRP Formulation  \
# ...

# %%
data.dtypes
# Out:
# Typeofsales        object
# Patient_ID          int64
# Specialisation     object
# Dept               object
# Dateofbill         object
# Quantity            int64
# ReturnQuantity      int64
# Final_Cost        float64
# Final_Sales       float64
# RtnMRP            float64
# Formulation        object
# DrugName           object
# SubCat             object
# SubCat1            object
# dtype: object

# %%
## Data Cleaning & Organizing; ##

#DUPLICATE 
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14213    False
# 14214    False
# 14215    False
# 14216    False
# 14217    False
# Length: 14218, dtype: bool

# %%
print(data.duplicated().sum())
# Out:
# 26

# %%
data2
# Out:
#       Typeofsales   Patient_ID    Specialisation         Dept  Dateofbill  \
# 0            Sale  12018098765   Specialisation6  Department1  06-01-2022
# 1            Sale  12018103897   Specialisation7  Department1   7/23/2022
# 2            Sale  12018101123   Specialisation2  Department3   6/23/2022
# 3            Sale  12018079281  Specialisation40  Department1   3/17/2022
# 4            Sale  12018117928   Specialisation5  Department1  12/21/2022
# ...           ...          ...               ...          ...         ...
# 14213        Sale  12018099994  Specialisation39  Department1   6/19/2022
# 14214        Sale  12018047025   Specialisation4  Department1   2/24/2022
# 14215        Sale  12018017139   Specialisation1  Department1   6/27/2022
# 14216        Sale  12018044140  Specialisation20  Department1   7/30/2022
# 14217        Sale  12018116820  Specialisation26  Department1  10/24/2022
#
#        Quantity  ReturnQuantity  Final_Cost  Final_Sales  RtnMRP Formulation  \
# ...

# %%
duplicate = data.duplicated() #Used to see Duplicate values in data set.
duplicate
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14213    False
# 14214    False
# 14215    False
# 14216    False
# 14217    False
# Length: 14218, dtype: bool

# %%
#Finding Duplicate values in whole data set.
sum(duplicate) # (it shows the sum of the duplicated value)

duplicate = data.duplicated(keep ='last')
duplicate
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14213    False
# 14214    False
# 14215    False
# 14216    False
# 14217    False
# Length: 14218, dtype: bool

# %%
data2 = data.drop_duplicates() #Delete the duplicate values
data2
sum(duplicate)
# Out:
# 26

# %%
# Identify missing values
missing_values = data.isnull()

# %%
missing_values.sum()
# Out:
# Typeofsales          0
# Patient_ID           0
# Specialisation       0
# Dept                 0
# Dateofbill           0
# Quantity             0
# ReturnQuantity       0
# Final_Cost           0
# Final_Sales          0
# RtnMRP               0
# Formulation        653
# DrugName          1668
# SubCat            1668
# SubCat1           1692
# dtype: int64

# %%
data
# Out:
#       Typeofsales   Patient_ID    Specialisation         Dept  Dateofbill  \
# 0            Sale  12018098765   Specialisation6  Department1  06-01-2022
# 1            Sale  12018103897   Specialisation7  Department1   7/23/2022
# 2            Sale  12018101123   Specialisation2  Department3   6/23/2022
# 3            Sale  12018079281  Specialisation40  Department1   3/17/2022
# 4            Sale  12018117928   Specialisation5  Department1  12/21/2022
# ...           ...          ...               ...          ...         ...
# 14213        Sale  12018099994  Specialisation39  Department1   6/19/2022
# 14214        Sale  12018047025   Specialisation4  Department1   2/24/2022
# 14215        Sale  12018017139   Specialisation1  Department1   6/27/2022
# 14216        Sale  12018044140  Specialisation20  Department1   7/30/2022
# 14217        Sale  12018116820  Specialisation26  Department1  10/24/2022
#
#        Quantity  ReturnQuantity  Final_Cost  Final_Sales  RtnMRP Formulation  \
# ...

# %%
import numpy as np
from sklearn.impute import KNNImputer

# Assuming you have a DataFrame 'df' with missing values

# Initialize the KNNImputer with the desired number of neighbors (k)
knn_imputer = KNNImputer(n_neighbors=5)  # You can adjust 'n_neighbors' as needed
data1 =  pd.DataFrame(data.Quantity)
# Fit and transform the DataFrame to perform k-NN imputation
data_imputed = knn_imputer.fit_transform(data1)

# The result is a NumPy array, so you can convert it back to a DataFrame if desired
df_imputed = pd.DataFrame(data_imputed, columns=data1.columns)
data.Quantity = df_imputed
data
# Now, 'df_imputed' contains the DataFrame with missing values imputed using k-NN
# Out:
#       Typeofsales   Patient_ID    Specialisation         Dept  Dateofbill  \
# 0            Sale  12018098765   Specialisation6  Department1  06-01-2022
# 1            Sale  12018103897   Specialisation7  Department1   7/23/2022
# 2            Sale  12018101123   Specialisation2  Department3   6/23/2022
# 3            Sale  12018079281  Specialisation40  Department1   3/17/2022
# 4            Sale  12018117928   Specialisation5  Department1  12/21/2022
# ...           ...          ...               ...          ...         ...
# 14213        Sale  12018099994  Specialisation39  Department1   6/19/2022
# 14214        Sale  12018047025   Specialisation4  Department1   2/24/2022
# 14215        Sale  12018017139   Specialisation1  Department1   6/27/2022
# 14216        Sale  12018044140  Specialisation20  Department1   7/30/2022
# 14217        Sale  12018116820  Specialisation26  Department1  10/24/2022
#
#        Quantity  ReturnQuantity  Final_Cost  Final_Sales  RtnMRP Formulation  \
# ...

# %%
data.isna().sum()
# Out:
# Typeofsales          0
# Patient_ID           0
# Specialisation       0
# Dept                 0
# Dateofbill           0
# Quantity             0
# ReturnQuantity       0
# Final_Cost           0
# Final_Sales          0
# RtnMRP               0
# Formulation        653
# DrugName          1668
# SubCat            1668
# SubCat1           1692
# dtype: int64
